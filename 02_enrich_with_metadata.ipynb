# %%
storage_account_name = "amazondatalake60302101" 
storage_account_key = "QquzNH6F0tT5k+A55uFMwMYsBBIZH8oDuQcZkpv65ffegLTfeVoEphGEJT230Z9ZXIKToM+hRVed+ASt9SED6A=="

# Set Spark configuration to access ADLS Gen2
spark.conf.set(
    f"fs.azure.account.key.{storage_account_name}.dfs.core.windows.net",
    storage_account_key
)

# %%
clean_reviews_path = "abfss://processed@amazondatalake60302101.dfs.core.windows.net/clean_reviews/" 
clean_reviews_df = spark.read.parquet(clean_reviews_path)

# %%
metadata_path = "abfss://raw@amazondatalake60302101.dfs.core.windows.net/meta_Electronics_fixed.json" 
metadata_df = spark.read.json(metadata_path)

# %%
metadata_df = metadata_df.select( 
"asin", 
"title", 
"brand", 
"price" 
)

# %%
enriched_df = clean_reviews_df.join( 
    metadata_df, 
    on="asin", 
    how="left" 
)

# %%
# Write enriched reviews to Silver layer in processed container
enriched_reviews_path = "abfss://processed@amazondatalake60302101.dfs.core.windows.net/enriched_reviews/"

enriched_df.write.mode("overwrite").parquet(enriched_reviews_path)

print("Enriched reviews written successfully.")
# Out:
# Enriched reviews written successfully.
